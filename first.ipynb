# %% [markdown]
# # 2026-03-20

# %%
print('Hello Python')
# Out:
# Hello Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 이것은 마크다운

# %% [markdown]
# ㅜㅜ

# %% [markdown]
# ㅋff
